# %%
#rom agent_visualiser import HierarchicalAgentVisualizer
from agent_visualiser_v2 import HierarchicalAgentVisualizer
# Create the visualizer
viz = HierarchicalAgentVisualizer()

# Generate just one plot to test
fig = viz.create_hierarchy_diagram()
